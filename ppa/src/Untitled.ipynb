# %%
import copy
from numpy import around
import random
from random import randrange
import time
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from route import Route
from tsp import TSP 


class PPA:


    def __init__(self, evaluations, pop_size, n_max, s_max, instance):
        self.instance = instance
        self.evaluations = evaluations
        self.number_evaluations = 0 
        self.pop_size = pop_size
        self.n_max = n_max
        self.s_max = s_max
        self.route_matrix = instance.matrix
        self.population = self.initialize_population(instance, pop_size)
        self.population_offspring = []
        self.generations = 0
        self.x_max = 0
        self.x_min = np.inf 
        self.end_generation = True
        self.best_route = None
        
    
    def initialize_population(self, tsp_instance, pop_size):
        route = Route(tsp_instance.cities)
        initial_pop = [Route(random.sample(route.route, route.length)) for n in range(self.pop_size)]
        for route in initial_pop:
            route.calculate_distance(tsp_instance)
            self.number_evaluations += 1
         
        return initial_pop        
    

    def fitness(self, route):
        """
        Normalize and calculate the fitness,
        f(xi) within an interval between [0,1] with 
        z_x_i = (f(x_max)-f(x_i))/(f(x_max)-f(x_min)) 
        """
        normalized_fitness = (self.x_max - route.route_distance) / (self.x_max - self.x_min)
        F_xi = 0.5 * (np.tanh(4 * (normalized_fitness) - 2) + 1)
        return F_xi
    

    def assign_offspring(self, F_xi):
        return int(np.ceil(self.n_max * F_xi * random.random()))
    

    def mutation(self, F_xi):
        return int(np.ceil(self.s_max * random.random() * (1 - F_xi)))    
    

    def create_new_offspring(self, route, number_offspring, number_mutation):
        for _ in range(1, number_offspring + 1):   
            offspring_route = route.copy()
            assert id(offspring_route) != id(route)

            for _ in range(1, number_mutation+1):
                offspring_route.two_opt()

            offspring_route.calculate_distance(self.instance)
            self.population_offspring.append(offspring_route)
            self.number_evaluations += 1

     
    def evaluate(self):
        """
        Evaluate while that there wont be more evaluations that 
        specified but if the eveluation is busy it will finish it.
        """
        while self.end_generation:
           
            sorted_route_list = sorted([x.route_distance for x in self.population])  
            self.x_max = sorted_route_list[-1]
            self.x_min = sorted_route_list[0]

            for route in self.population:
                if  self.number_evaluations >= self.evaluations:
                    self.end_generation = False
                
                # The fitness is calculated for eacht route. 
                # If the X_max is equal to the X_min than all 
                # the fitness values will be 0.5
                if(self.x_max == self.x_min):
                    F_xi = 0.5
                else: 
                    F_xi = self.fitness(route)
                
                number_offspring = self.assign_offspring(F_xi)
                number_mutation = self.mutation(F_xi)     
                self.create_new_offspring(route, number_offspring, number_mutation)
                
        
            self.population = self.population + self.population_offspring
            self.population = sorted(self.population, key=lambda route: route.route_distance)[:self.pop_size]
        
            self.population_offspring = []

            # Save the best route and update if there is a better route.
            if self.best_route is None:
                self.best_route = self.population[0]
            elif self.best_route.route_distance > self.population[0].route_distance:
                self.best_route = self.population[0]
               
        return self.best_route.route_distance


def main():
    tsp = TSP("../data/instance_1.tsp.txt")     
    n_pop_size = 40 
    n_offspring = 10
    n_evaluations = 5000
    n_mutations = 20
    n_runs = 5

    arr = np.zeros((n_pop_size -1, n_offspring -1))

    
    for pop_size_i, pop_size in enumerate(range(2, n_pop_size + 1)):
        for offspring_i, max_offspring in enumerate(range(2, n_offspring + 1)):
            
            start = time.time()

            value = 0 
            
            for _ in range(n_runs):
                ppa = PPA(n_evaluations, pop_size, max_offspring, n_mutations, tsp)
                value += ppa.evaluate()
            mean = float(value) / n_runs

            end = time.time()

            print(f"Processing time: {round(end - start, 3)} seconds")
            arr[pop_size_i, offspring_i] = mean
            print(f"number of pop_size: {pop_size} and countsize for pop,off {pop_size_i},{offspring_i} number of offspring {max_offspring} with {mean} value")
    
   
    fig = plt.figure(figsize=(18, 9.6))
    ax = fig.add_subplot(111)
    ax.set_title('colorMap')
    plt.imshow(arr)
    ax.set_aspect('equal')

    plt.colorbar(orientation='vertical')
    plt.show()


if __name__ == '__main__':
    main()
# Out:
# Processing time: 0.815 seconds
# number of pop_size: 2 and countsize for pop,off 0,0 number of offspring 2 with 48980.4 value
# Processing time: 0.778 seconds
# number of pop_size: 2 and countsize for pop,off 0,1 number of offspring 3 with 49032.4 value
# Processing time: 0.755 seconds
# number of pop_size: 2 and countsize for pop,off 0,2 number of offspring 4 with 47689.6 value
# Processing time: 0.739 seconds
# number of pop_size: 2 and countsize for pop,off 0,3 number of offspring 5 with 48578.0 value
# Processing time: 0.696 seconds
# number of pop_size: 2 and countsize for pop,off 0,4 number of offspring 6 with 45196.6 value
# Processing time: 0.687 seconds
# number of pop_size: 2 and countsize for pop,off 0,5 number of offspring 7 with 48093.4 value
# Processing time: 0.677 seconds
# number of pop_size: 2 and countsize for pop,off 0,6 number of offspring 8 with 51357.2 value
# Processing time: 0.668 seconds
# number of pop_size: 2 and countsize for pop,off 0,7 number of offspring 9 with 51634.4 value
# Processing time: 0.674 seconds
# number of pop_size: 2 and countsize for pop,off 0,8 number of offspring 10 with 47482.4 value
# Processing time: 0.82 seconds
# number of pop_size: 3 and countsize for pop,off 1,0 number of offspring 2 with 52884.8 value
# Processing time: 0.806 seconds
# number of pop_size: 3 and countsize for pop,off 1,1 number of offspring 3 with 49907.4 value
# Processing time: 0.762 seconds
# number of pop_size: 3 and countsize for pop,off 1,2 number of offspring 4 with 48443.4 value
# Processing time: 0.75 seconds
# number of pop_size: 3 and countsize for pop,off 1,3 number of offspring 5 with 47972.8 value
# Processing time: 0.723 seconds
# number of pop_size: 3 and countsize for pop,off 1,4 number of offspring 6 with 49552.2 value
# Processing time: 0.704 seconds
# number of pop_size: 3 and countsize for pop,off 1,5 number of offspring 7 with 46681.2 value
# Processing time: 0.703 seconds
# number of pop_size: 3 and countsize for pop,off 1,6 number of offspring 8 with 51225.6 value
# Processing time: 0.709 seconds
# number of pop_size: 3 and countsize for pop,off 1,7 number of offspring 9 with 50479.4 value
# Processing time: 0.696 seconds
# number of pop_size: 3 and countsize for pop,off 1,8 number of offspring 10 with 45714.2 value
# Processing time: 0.832 seconds
# number of pop_size: 4 and countsize for pop,off 2,0 number of offspring 2 with 47500.6 value
# Processing time: 0.793 seconds
# number of pop_size: 4 and countsize for pop,off 2,1 number of offspring 3 with 50465.6 value
# Processing time: 0.767 seconds
# number of pop_size: 4 and countsize for pop,off 2,2 number of offspring 4 with 51973.2 value
# Processing time: 0.776 seconds
# number of pop_size: 4 and countsize for pop,off 2,3 number of offspring 5 with 52356.2 value
# Processing time: 0.745 seconds
# number of pop_size: 4 and countsize for pop,off 2,4 number of offspring 6 with 50579.4 value
# Processing time: 0.73 seconds
# number of pop_size: 4 and countsize for pop,off 2,5 number of offspring 7 with 49357.8 value
# Processing time: 0.719 seconds
# number of pop_size: 4 and countsize for pop,off 2,6 number of offspring 8 with 48682.0 value
# Processing time: 0.699 seconds
# number of pop_size: 4 and countsize for pop,off 2,7 number of offspring 9 with 51364.0 value
# Processing time: 0.712 seconds
# number of pop_size: 4 and countsize for pop,off 2,8 number of offspring 10 with 50731.0 value
# Processing time: 0.858 seconds
# number of pop_size: 5 and countsize for pop,off 3,0 number of offspring 2 with 54652.6 value
# Processing time: 0.828 seconds
# number of pop_size: 5 and countsize for pop,off 3,1 number of offspring 3 with 54319.8 value
# Processing time: 0.799 seconds
# number of pop_size: 5 and countsize for pop,off 3,2 number of offspring 4 with 50148.4 value
# Processing time: 0.772 seconds
# number of pop_size: 5 and countsize for pop,off 3,3 number of offspring 5 with 51028.8 value
# Processing time: 0.77 seconds
# number of pop_size: 5 and countsize for pop,off 3,4 number of offspring 6 with 53897.2 value
# Processing time: 0.75 seconds
# number of pop_size: 5 and countsize for pop,off 3,5 number of offspring 7 with 50063.2 value
# Processing time: 0.738 seconds
# number of pop_size: 5 and countsize for pop,off 3,6 number of offspring 8 with 48824.2 value
# Processing time: 0.727 seconds
# number of pop_size: 5 and countsize for pop,off 3,7 number of offspring 9 with 52244.8 value
# Processing time: 0.723 seconds
# number of pop_size: 5 and countsize for pop,off 3,8 number of offspring 10 with 48236.0 value
# Processing time: 0.85 seconds
# number of pop_size: 6 and countsize for pop,off 4,0 number of offspring 2 with 53295.4 value
# Processing time: 0.841 seconds
# number of pop_size: 6 and countsize for pop,off 4,1 number of offspring 3 with 53139.8 value
# Processing time: 0.805 seconds
# number of pop_size: 6 and countsize for pop,off 4,2 number of offspring 4 with 50802.6 value
# Processing time: 0.778 seconds
# number of pop_size: 6 and countsize for pop,off 4,3 number of offspring 5 with 56727.8 value
# Processing time: 0.776 seconds
# number of pop_size: 6 and countsize for pop,off 4,4 number of offspring 6 with 50915.2 value
# Processing time: 0.758 seconds
# number of pop_size: 6 and countsize for pop,off 4,5 number of offspring 7 with 50746.6 value
# Processing time: 0.742 seconds
# number of pop_size: 6 and countsize for pop,off 4,6 number of offspring 8 with 52196.2 value
# Processing time: 0.709 seconds
# number of pop_size: 6 and countsize for pop,off 4,7 number of offspring 9 with 53400.6 value
# Processing time: 0.7 seconds
# number of pop_size: 6 and countsize for pop,off 4,8 number of offspring 10 with 52464.6 value
# Processing time: 0.838 seconds
# number of pop_size: 7 and countsize for pop,off 5,0 number of offspring 2 with 50445.8 value
# Processing time: 0.823 seconds
# number of pop_size: 7 and countsize for pop,off 5,1 number of offspring 3 with 54653.4 value
# Processing time: 0.807 seconds
# number of pop_size: 7 and countsize for pop,off 5,2 number of offspring 4 with 53509.6 value
# Processing time: 0.788 seconds
# number of pop_size: 7 and countsize for pop,off 5,3 number of offspring 5 with 52022.8 value
# Processing time: 0.776 seconds
# number of pop_size: 7 and countsize for pop,off 5,4 number of offspring 6 with 51915.0 value
# Processing time: 0.76 seconds
# number of pop_size: 7 and countsize for pop,off 5,5 number of offspring 7 with 53791.4 value
# Processing time: 0.748 seconds
# number of pop_size: 7 and countsize for pop,off 5,6 number of offspring 8 with 51820.6 value
# Processing time: 0.74 seconds
# number of pop_size: 7 and countsize for pop,off 5,7 number of offspring 9 with 49487.6 value
# Processing time: 0.769 seconds
# number of pop_size: 7 and countsize for pop,off 5,8 number of offspring 10 with 50262.2 value
# Processing time: 0.929 seconds
# number of pop_size: 8 and countsize for pop,off 6,0 number of offspring 2 with 53905.8 value
# Processing time: 0.902 seconds
# number of pop_size: 8 and countsize for pop,off 6,1 number of offspring 3 with 51762.0 value
# Processing time: 0.829 seconds
# number of pop_size: 8 and countsize for pop,off 6,2 number of offspring 4 with 53886.2 value
# Processing time: 0.836 seconds
# number of pop_size: 8 and countsize for pop,off 6,3 number of offspring 5 with 55525.6 value
# Processing time: 0.831 seconds
# number of pop_size: 8 and countsize for pop,off 6,4 number of offspring 6 with 55932.2 value
# Processing time: 0.778 seconds
# number of pop_size: 8 and countsize for pop,off 6,5 number of offspring 7 with 51835.2 value
# Processing time: 0.831 seconds
# number of pop_size: 8 and countsize for pop,off 6,6 number of offspring 8 with 51444.0 value
# Processing time: 0.787 seconds
# number of pop_size: 8 and countsize for pop,off 6,7 number of offspring 9 with 50751.2 value
# Processing time: 0.786 seconds
# number of pop_size: 8 and countsize for pop,off 6,8 number of offspring 10 with 53785.0 value
# Processing time: 0.913 seconds
# number of pop_size: 9 and countsize for pop,off 7,0 number of offspring 2 with 59434.0 value
# Processing time: 0.891 seconds
# number of pop_size: 9 and countsize for pop,off 7,1 number of offspring 3 with 58607.2 value
# Processing time: 0.874 seconds
# number of pop_size: 9 and countsize for pop,off 7,2 number of offspring 4 with 53587.8 value
# Processing time: 0.845 seconds
# number of pop_size: 9 and countsize for pop,off 7,3 number of offspring 5 with 52342.6 value
# Processing time: 0.832 seconds
# number of pop_size: 9 and countsize for pop,off 7,4 number of offspring 6 with 54778.4 value
# Processing time: 0.791 seconds
# number of pop_size: 9 and countsize for pop,off 7,5 number of offspring 7 with 51610.6 value
# Processing time: 0.792 seconds
# number of pop_size: 9 and countsize for pop,off 7,6 number of offspring 8 with 54477.2 value
# Processing time: 0.774 seconds
# number of pop_size: 9 and countsize for pop,off 7,7 number of offspring 9 with 53765.2 value
# Processing time: 0.756 seconds
# number of pop_size: 9 and countsize for pop,off 7,8 number of offspring 10 with 53227.2 value
# Processing time: 0.892 seconds
# number of pop_size: 10 and countsize for pop,off 8,0 number of offspring 2 with 58749.2 value
# Processing time: 0.874 seconds
# number of pop_size: 10 and countsize for pop,off 8,1 number of offspring 3 with 56410.2 value
# Processing time: 0.839 seconds
# number of pop_size: 10 and countsize for pop,off 8,2 number of offspring 4 with 57337.6 value
# Processing time: 0.809 seconds
# number of pop_size: 10 and countsize for pop,off 8,3 number of offspring 5 with 54142.0 value
# Processing time: 0.79 seconds
# number of pop_size: 10 and countsize for pop,off 8,4 number of offspring 6 with 51922.4 value
# Processing time: 0.78 seconds
# number of pop_size: 10 and countsize for pop,off 8,5 number of offspring 7 with 52522.4 value
# Processing time: 0.774 seconds
# number of pop_size: 10 and countsize for pop,off 8,6 number of offspring 8 with 58031.8 value
# Processing time: 0.772 seconds
# number of pop_size: 10 and countsize for pop,off 8,7 number of offspring 9 with 55905.4 value
# Processing time: 0.752 seconds
# number of pop_size: 10 and countsize for pop,off 8,8 number of offspring 10 with 51818.0 value
# Processing time: 0.896 seconds
# number of pop_size: 11 and countsize for pop,off 9,0 number of offspring 2 with 59191.4 value
# Processing time: 0.853 seconds
# number of pop_size: 11 and countsize for pop,off 9,1 number of offspring 3 with 55344.6 value
# Processing time: 0.829 seconds
# number of pop_size: 11 and countsize for pop,off 9,2 number of offspring 4 with 52509.2 value
# Processing time: 0.816 seconds
# number of pop_size: 11 and countsize for pop,off 9,3 number of offspring 5 with 53288.4 value
# Processing time: 0.795 seconds
# number of pop_size: 11 and countsize for pop,off 9,4 number of offspring 6 with 52926.8 value
# Processing time: 0.786 seconds
# number of pop_size: 11 and countsize for pop,off 9,5 number of offspring 7 with 49936.8 value
# Processing time: 0.775 seconds
# number of pop_size: 11 and countsize for pop,off 9,6 number of offspring 8 with 53769.0 value
# Processing time: 0.76 seconds
# number of pop_size: 11 and countsize for pop,off 9,7 number of offspring 9 with 52117.2 value
# Processing time: 0.764 seconds
# number of pop_size: 11 and countsize for pop,off 9,8 number of offspring 10 with 52609.2 value
# Processing time: 0.897 seconds
# number of pop_size: 12 and countsize for pop,off 10,0 number of offspring 2 with 54864.4 value
# Processing time: 0.915 seconds
# number of pop_size: 12 and countsize for pop,off 10,1 number of offspring 3 with 52007.0 value
# Processing time: 0.875 seconds
# number of pop_size: 12 and countsize for pop,off 10,2 number of offspring 4 with 58721.0 value
# Processing time: 0.813 seconds
# number of pop_size: 12 and countsize for pop,off 10,3 number of offspring 5 with 52338.4 value
# Processing time: 0.794 seconds
# number of pop_size: 12 and countsize for pop,off 10,4 number of offspring 6 with 53516.6 value
# Processing time: 0.792 seconds
# number of pop_size: 12 and countsize for pop,off 10,5 number of offspring 7 with 54788.8 value
# Processing time: 0.79 seconds
# number of pop_size: 12 and countsize for pop,off 10,6 number of offspring 8 with 53917.4 value
# Processing time: 0.782 seconds
# number of pop_size: 12 and countsize for pop,off 10,7 number of offspring 9 with 51197.2 value
# Processing time: 0.75 seconds
# number of pop_size: 12 and countsize for pop,off 10,8 number of offspring 10 with 54581.6 value
# Processing time: 0.889 seconds
# number of pop_size: 13 and countsize for pop,off 11,0 number of offspring 2 with 56127.2 value
# Processing time: 0.856 seconds
# number of pop_size: 13 and countsize for pop,off 11,1 number of offspring 3 with 54370.0 value
# Processing time: 0.825 seconds
# number of pop_size: 13 and countsize for pop,off 11,2 number of offspring 4 with 56003.2 value
# Processing time: 0.818 seconds
# number of pop_size: 13 and countsize for pop,off 11,3 number of offspring 5 with 55850.6 value
# Processing time: 0.805 seconds
# number of pop_size: 13 and countsize for pop,off 11,4 number of offspring 6 with 57825.4 value
# Processing time: 0.797 seconds
# number of pop_size: 13 and countsize for pop,off 11,5 number of offspring 7 with 53707.6 value
# Processing time: 0.782 seconds
# number of pop_size: 13 and countsize for pop,off 11,6 number of offspring 8 with 53362.8 value
# Processing time: 0.755 seconds
# number of pop_size: 13 and countsize for pop,off 11,7 number of offspring 9 with 54743.8 value
# Processing time: 0.739 seconds
# number of pop_size: 13 and countsize for pop,off 11,8 number of offspring 10 with 54154.2 value
# Processing time: 0.896 seconds
# number of pop_size: 14 and countsize for pop,off 12,0 number of offspring 2 with 57018.0 value
# Processing time: 0.858 seconds
# number of pop_size: 14 and countsize for pop,off 12,1 number of offspring 3 with 58398.8 value
# Processing time: 0.831 seconds
# number of pop_size: 14 and countsize for pop,off 12,2 number of offspring 4 with 55054.4 value
# Processing time: 0.812 seconds
# number of pop_size: 14 and countsize for pop,off 12,3 number of offspring 5 with 52646.8 value
# Processing time: 0.809 seconds
# number of pop_size: 14 and countsize for pop,off 12,4 number of offspring 6 with 52698.0 value
# Processing time: 0.789 seconds
# number of pop_size: 14 and countsize for pop,off 12,5 number of offspring 7 with 56671.8 value
# Processing time: 0.772 seconds
# number of pop_size: 14 and countsize for pop,off 12,6 number of offspring 8 with 55120.4 value
# Processing time: 0.775 seconds
# number of pop_size: 14 and countsize for pop,off 12,7 number of offspring 9 with 53841.2 value
# Processing time: 0.884 seconds
# number of pop_size: 14 and countsize for pop,off 12,8 number of offspring 10 with 56392.6 value
# Processing time: 0.887 seconds
# number of pop_size: 15 and countsize for pop,off 13,0 number of offspring 2 with 60933.8 value
# Processing time: 0.852 seconds
# number of pop_size: 15 and countsize for pop,off 13,1 number of offspring 3 with 56435.6 value
# Processing time: 0.834 seconds
# number of pop_size: 15 and countsize for pop,off 13,2 number of offspring 4 with 57020.8 value
# Processing time: 0.811 seconds
# number of pop_size: 15 and countsize for pop,off 13,3 number of offspring 5 with 53097.2 value
# Processing time: 0.786 seconds
# number of pop_size: 15 and countsize for pop,off 13,4 number of offspring 6 with 56876.8 value
# Processing time: 0.781 seconds
# number of pop_size: 15 and countsize for pop,off 13,5 number of offspring 7 with 54612.0 value
# Processing time: 0.772 seconds
# number of pop_size: 15 and countsize for pop,off 13,6 number of offspring 8 with 57515.4 value
# Processing time: 0.756 seconds
# number of pop_size: 15 and countsize for pop,off 13,7 number of offspring 9 with 56546.6 value
# Processing time: 0.731 seconds
# number of pop_size: 15 and countsize for pop,off 13,8 number of offspring 10 with 54896.6 value
# Processing time: 0.853 seconds
# number of pop_size: 16 and countsize for pop,off 14,0 number of offspring 2 with 58462.8 value
# Processing time: 0.82 seconds
# number of pop_size: 16 and countsize for pop,off 14,1 number of offspring 3 with 59895.8 value
# Processing time: 0.804 seconds
# number of pop_size: 16 and countsize for pop,off 14,2 number of offspring 4 with 60237.6 value
# Processing time: 0.781 seconds
# number of pop_size: 16 and countsize for pop,off 14,3 number of offspring 5 with 52749.8 value
# Processing time: 0.78 seconds
# number of pop_size: 16 and countsize for pop,off 14,4 number of offspring 6 with 54813.6 value
# Processing time: 0.792 seconds
# number of pop_size: 16 and countsize for pop,off 14,5 number of offspring 7 with 54550.6 value
# Processing time: 0.756 seconds
# number of pop_size: 16 and countsize for pop,off 14,6 number of offspring 8 with 55650.8 value
# Processing time: 0.733 seconds
# number of pop_size: 16 and countsize for pop,off 14,7 number of offspring 9 with 60374.2 value
# Processing time: 0.719 seconds
# number of pop_size: 16 and countsize for pop,off 14,8 number of offspring 10 with 58087.0 value
# Processing time: 0.876 seconds
# number of pop_size: 17 and countsize for pop,off 15,0 number of offspring 2 with 61219.2 value
# Processing time: 0.85 seconds
# number of pop_size: 17 and countsize for pop,off 15,1 number of offspring 3 with 56038.0 value
# Processing time: 0.816 seconds
# number of pop_size: 17 and countsize for pop,off 15,2 number of offspring 4 with 55823.4 value
# Processing time: 0.788 seconds
# number of pop_size: 17 and countsize for pop,off 15,3 number of offspring 5 with 56115.4 value
# Processing time: 0.772 seconds
# number of pop_size: 17 and countsize for pop,off 15,4 number of offspring 6 with 58479.6 value
# Processing time: 0.761 seconds
# number of pop_size: 17 and countsize for pop,off 15,5 number of offspring 7 with 55136.2 value
# Processing time: 0.755 seconds
# number of pop_size: 17 and countsize for pop,off 15,6 number of offspring 8 with 55433.8 value
# Processing time: 0.816 seconds
# number of pop_size: 17 and countsize for pop,off 15,7 number of offspring 9 with 55822.8 value
# Processing time: 0.723 seconds
# number of pop_size: 17 and countsize for pop,off 15,8 number of offspring 10 with 54754.6 value
# Processing time: 0.947 seconds
# number of pop_size: 18 and countsize for pop,off 16,0 number of offspring 2 with 62912.4 value
# Processing time: 0.822 seconds
# number of pop_size: 18 and countsize for pop,off 16,1 number of offspring 3 with 58150.8 value
# Processing time: 0.804 seconds
# number of pop_size: 18 and countsize for pop,off 16,2 number of offspring 4 with 55799.2 value
# Processing time: 0.815 seconds
# number of pop_size: 18 and countsize for pop,off 16,3 number of offspring 5 with 55774.0 value
# Processing time: 0.79 seconds
# number of pop_size: 18 and countsize for pop,off 16,4 number of offspring 6 with 59250.8 value
# Processing time: 0.768 seconds
# number of pop_size: 18 and countsize for pop,off 16,5 number of offspring 7 with 54140.0 value
# Processing time: 0.779 seconds
# number of pop_size: 18 and countsize for pop,off 16,6 number of offspring 8 with 59729.0 value
# Processing time: 0.771 seconds
# number of pop_size: 18 and countsize for pop,off 16,7 number of offspring 9 with 55430.6 value
# Processing time: 0.75 seconds
# number of pop_size: 18 and countsize for pop,off 16,8 number of offspring 10 with 54477.4 value
# Processing time: 0.872 seconds
# number of pop_size: 19 and countsize for pop,off 17,0 number of offspring 2 with 64575.2 value
# Processing time: 0.83 seconds
# number of pop_size: 19 and countsize for pop,off 17,1 number of offspring 3 with 58196.0 value
# Processing time: 0.775 seconds
# number of pop_size: 19 and countsize for pop,off 17,2 number of offspring 4 with 57430.0 value
# Processing time: 0.806 seconds
# number of pop_size: 19 and countsize for pop,off 17,3 number of offspring 5 with 56302.6 value
# Processing time: 0.795 seconds
# number of pop_size: 19 and countsize for pop,off 17,4 number of offspring 6 with 55739.0 value
# Processing time: 0.757 seconds
# number of pop_size: 19 and countsize for pop,off 17,5 number of offspring 7 with 57363.2 value
# Processing time: 0.744 seconds
# number of pop_size: 19 and countsize for pop,off 17,6 number of offspring 8 with 58492.4 value
# Processing time: 0.739 seconds
# number of pop_size: 19 and countsize for pop,off 17,7 number of offspring 9 with 57240.8 value
# Processing time: 0.732 seconds
# number of pop_size: 19 and countsize for pop,off 17,8 number of offspring 10 with 59684.6 value
# Processing time: 0.865 seconds
# number of pop_size: 20 and countsize for pop,off 18,0 number of offspring 2 with 60161.0 value
# Processing time: 0.824 seconds
# number of pop_size: 20 and countsize for pop,off 18,1 number of offspring 3 with 55179.4 value
# Processing time: 0.802 seconds
# number of pop_size: 20 and countsize for pop,off 18,2 number of offspring 4 with 57645.4 value
# Processing time: 0.792 seconds
# number of pop_size: 20 and countsize for pop,off 18,3 number of offspring 5 with 54979.8 value
# Processing time: 0.781 seconds
# number of pop_size: 20 and countsize for pop,off 18,4 number of offspring 6 with 58325.0 value
# Processing time: 0.764 seconds
# number of pop_size: 20 and countsize for pop,off 18,5 number of offspring 7 with 58070.4 value
# Processing time: 0.747 seconds
# number of pop_size: 20 and countsize for pop,off 18,6 number of offspring 8 with 59565.2 value
# Processing time: 0.768 seconds
# number of pop_size: 20 and countsize for pop,off 18,7 number of offspring 9 with 57096.8 value
# Processing time: 0.765 seconds
# number of pop_size: 20 and countsize for pop,off 18,8 number of offspring 10 with 55066.2 value
# Processing time: 0.85 seconds
# number of pop_size: 21 and countsize for pop,off 19,0 number of offspring 2 with 60056.8 value
# Processing time: 0.801 seconds
# number of pop_size: 21 and countsize for pop,off 19,1 number of offspring 3 with 57838.6 value
# Processing time: 0.777 seconds
# number of pop_size: 21 and countsize for pop,off 19,2 number of offspring 4 with 58293.6 value
# Processing time: 0.763 seconds
# number of pop_size: 21 and countsize for pop,off 19,3 number of offspring 5 with 59545.2 value
# Processing time: 0.749 seconds
# number of pop_size: 21 and countsize for pop,off 19,4 number of offspring 6 with 54386.6 value
# Processing time: 0.745 seconds
# number of pop_size: 21 and countsize for pop,off 19,5 number of offspring 7 with 58108.6 value
# Processing time: 0.729 seconds
# number of pop_size: 21 and countsize for pop,off 19,6 number of offspring 8 with 55344.6 value
# Processing time: 0.752 seconds
# number of pop_size: 21 and countsize for pop,off 19,7 number of offspring 9 with 58560.8 value
# Processing time: 0.764 seconds
# number of pop_size: 21 and countsize for pop,off 19,8 number of offspring 10 with 55361.6 value
# Processing time: 0.898 seconds
# number of pop_size: 22 and countsize for pop,off 20,0 number of offspring 2 with 60988.6 value
# Processing time: 0.871 seconds
# number of pop_size: 22 and countsize for pop,off 20,1 number of offspring 3 with 58669.0 value
# Processing time: 0.812 seconds
# number of pop_size: 22 and countsize for pop,off 20,2 number of offspring 4 with 60644.0 value
# Processing time: 0.785 seconds
# number of pop_size: 22 and countsize for pop,off 20,3 number of offspring 5 with 56984.4 value
# Processing time: 0.785 seconds
# number of pop_size: 22 and countsize for pop,off 20,4 number of offspring 6 with 58992.2 value
# Processing time: 0.759 seconds
# number of pop_size: 22 and countsize for pop,off 20,5 number of offspring 7 with 56818.2 value
# Processing time: 0.786 seconds
# number of pop_size: 22 and countsize for pop,off 20,6 number of offspring 8 with 60235.6 value
# Processing time: 0.777 seconds
# number of pop_size: 22 and countsize for pop,off 20,7 number of offspring 9 with 60211.8 value
# Processing time: 0.767 seconds
# number of pop_size: 22 and countsize for pop,off 20,8 number of offspring 10 with 56294.4 value
# Processing time: 0.87 seconds
# number of pop_size: 23 and countsize for pop,off 21,0 number of offspring 2 with 62341.0 value
# Processing time: 0.863 seconds
# number of pop_size: 23 and countsize for pop,off 21,1 number of offspring 3 with 60907.6 value
# Processing time: 0.83 seconds
# number of pop_size: 23 and countsize for pop,off 21,2 number of offspring 4 with 61584.4 value
# Processing time: 0.806 seconds
# number of pop_size: 23 and countsize for pop,off 21,3 number of offspring 5 with 58440.4 value
# Processing time: 0.771 seconds
# number of pop_size: 23 and countsize for pop,off 21,4 number of offspring 6 with 57554.2 value
# Processing time: 0.75 seconds
# number of pop_size: 23 and countsize for pop,off 21,5 number of offspring 7 with 62817.6 value
# Processing time: 0.742 seconds
# number of pop_size: 23 and countsize for pop,off 21,6 number of offspring 8 with 59336.8 value
# Processing time: 0.733 seconds
# number of pop_size: 23 and countsize for pop,off 21,7 number of offspring 9 with 56531.2 value
# Processing time: 0.74 seconds
# number of pop_size: 23 and countsize for pop,off 21,8 number of offspring 10 with 60513.0 value
# Processing time: 0.845 seconds
# number of pop_size: 24 and countsize for pop,off 22,0 number of offspring 2 with 60483.0 value
# Processing time: 0.816 seconds
# number of pop_size: 24 and countsize for pop,off 22,1 number of offspring 3 with 59244.6 value
# Processing time: 0.791 seconds
# number of pop_size: 24 and countsize for pop,off 22,2 number of offspring 4 with 57464.6 value
# Processing time: 0.78 seconds
# number of pop_size: 24 and countsize for pop,off 22,3 number of offspring 5 with 62852.2 value
# Processing time: 0.762 seconds
# number of pop_size: 24 and countsize for pop,off 22,4 number of offspring 6 with 58652.2 value
# Processing time: 0.749 seconds
# number of pop_size: 24 and countsize for pop,off 22,5 number of offspring 7 with 58885.8 value
# Processing time: 0.741 seconds
# number of pop_size: 24 and countsize for pop,off 22,6 number of offspring 8 with 56812.8 value
# Processing time: 0.742 seconds
# number of pop_size: 24 and countsize for pop,off 22,7 number of offspring 9 with 62026.0 value
# Processing time: 0.735 seconds
# number of pop_size: 24 and countsize for pop,off 22,8 number of offspring 10 with 58307.2 value
# Processing time: 0.838 seconds
# number of pop_size: 25 and countsize for pop,off 23,0 number of offspring 2 with 58705.2 value
# Processing time: 0.797 seconds
# number of pop_size: 25 and countsize for pop,off 23,1 number of offspring 3 with 59849.8 value
# Processing time: 0.771 seconds
# number of pop_size: 25 and countsize for pop,off 23,2 number of offspring 4 with 62201.6 value
# Processing time: 0.78 seconds
# number of pop_size: 25 and countsize for pop,off 23,3 number of offspring 5 with 57067.4 value
# Processing time: 0.771 seconds
# number of pop_size: 25 and countsize for pop,off 23,4 number of offspring 6 with 59004.6 value
# Processing time: 0.748 seconds
# number of pop_size: 25 and countsize for pop,off 23,5 number of offspring 7 with 55996.0 value
# Processing time: 0.74 seconds
# number of pop_size: 25 and countsize for pop,off 23,6 number of offspring 8 with 58245.4 value
# Processing time: 0.761 seconds
# number of pop_size: 25 and countsize for pop,off 23,7 number of offspring 9 with 58564.6 value
# Processing time: 0.754 seconds
# number of pop_size: 25 and countsize for pop,off 23,8 number of offspring 10 with 60355.6 value
# Processing time: 0.853 seconds
# number of pop_size: 26 and countsize for pop,off 24,0 number of offspring 2 with 64486.6 value
# Processing time: 0.816 seconds
# number of pop_size: 26 and countsize for pop,off 24,1 number of offspring 3 with 61235.2 value
# Processing time: 0.828 seconds
# number of pop_size: 26 and countsize for pop,off 24,2 number of offspring 4 with 61476.4 value
# Processing time: 0.825 seconds
# number of pop_size: 26 and countsize for pop,off 24,3 number of offspring 5 with 60035.4 value
# Processing time: 0.797 seconds
# number of pop_size: 26 and countsize for pop,off 24,4 number of offspring 6 with 60577.6 value
# Processing time: 0.773 seconds
# number of pop_size: 26 and countsize for pop,off 24,5 number of offspring 7 with 60860.8 value
# Processing time: 0.753 seconds
# number of pop_size: 26 and countsize for pop,off 24,6 number of offspring 8 with 59832.0 value
# Processing time: 0.782 seconds
# number of pop_size: 26 and countsize for pop,off 24,7 number of offspring 9 with 57160.8 value
# Processing time: 0.761 seconds
# number of pop_size: 26 and countsize for pop,off 24,8 number of offspring 10 with 61063.0 value
# Processing time: 0.86 seconds
# number of pop_size: 27 and countsize for pop,off 25,0 number of offspring 2 with 64637.8 value
# Processing time: 0.841 seconds
# number of pop_size: 27 and countsize for pop,off 25,1 number of offspring 3 with 61284.8 value
# Processing time: 0.807 seconds
# number of pop_size: 27 and countsize for pop,off 25,2 number of offspring 4 with 58818.6 value
# Processing time: 0.824 seconds
# number of pop_size: 27 and countsize for pop,off 25,3 number of offspring 5 with 60399.2 value
# Processing time: 0.776 seconds
# number of pop_size: 27 and countsize for pop,off 25,4 number of offspring 6 with 61195.4 value
# Processing time: 0.786 seconds
# number of pop_size: 27 and countsize for pop,off 25,5 number of offspring 7 with 58222.8 value
# Processing time: 0.765 seconds
# number of pop_size: 27 and countsize for pop,off 25,6 number of offspring 8 with 61125.8 value
# Processing time: 0.753 seconds
# number of pop_size: 27 and countsize for pop,off 25,7 number of offspring 9 with 60866.4 value
# Processing time: 0.766 seconds
# number of pop_size: 27 and countsize for pop,off 25,8 number of offspring 10 with 59259.6 value
# Processing time: 0.885 seconds
# number of pop_size: 28 and countsize for pop,off 26,0 number of offspring 2 with 63669.6 value
# Processing time: 0.866 seconds
# number of pop_size: 28 and countsize for pop,off 26,1 number of offspring 3 with 58445.2 value
# Processing time: 0.851 seconds
# number of pop_size: 28 and countsize for pop,off 26,2 number of offspring 4 with 60729.2 value
# Processing time: 0.834 seconds
# number of pop_size: 28 and countsize for pop,off 26,3 number of offspring 5 with 59129.0 value
# Processing time: 0.853 seconds
# number of pop_size: 28 and countsize for pop,off 26,4 number of offspring 6 with 62661.8 value
# Processing time: 0.795 seconds
# number of pop_size: 28 and countsize for pop,off 26,5 number of offspring 7 with 61976.2 value
# Processing time: 0.773 seconds
# number of pop_size: 28 and countsize for pop,off 26,6 number of offspring 8 with 59206.8 value
# Processing time: 0.776 seconds
# number of pop_size: 28 and countsize for pop,off 26,7 number of offspring 9 with 58644.4 value
# Processing time: 0.814 seconds
# number of pop_size: 28 and countsize for pop,off 26,8 number of offspring 10 with 58784.0 value
# Processing time: 0.983 seconds
# number of pop_size: 29 and countsize for pop,off 27,0 number of offspring 2 with 64157.2 value
# Processing time: 0.852 seconds
# number of pop_size: 29 and countsize for pop,off 27,1 number of offspring 3 with 61814.0 value
# Processing time: 0.808 seconds
# number of pop_size: 29 and countsize for pop,off 27,2 number of offspring 4 with 62253.2 value
# Processing time: 0.798 seconds
# number of pop_size: 29 and countsize for pop,off 27,3 number of offspring 5 with 60492.4 value
# Processing time: 0.78 seconds
# number of pop_size: 29 and countsize for pop,off 27,4 number of offspring 6 with 57798.8 value
# Processing time: 0.76 seconds
# number of pop_size: 29 and countsize for pop,off 27,5 number of offspring 7 with 58190.2 value
# Processing time: 0.778 seconds
# number of pop_size: 29 and countsize for pop,off 27,6 number of offspring 8 with 59053.4 value
# Processing time: 0.766 seconds
# number of pop_size: 29 and countsize for pop,off 27,7 number of offspring 9 with 56157.6 value
# Processing time: 0.73 seconds
# number of pop_size: 29 and countsize for pop,off 27,8 number of offspring 10 with 58639.8 value
# Processing time: 0.885 seconds
# number of pop_size: 30 and countsize for pop,off 28,0 number of offspring 2 with 65980.0 value
# Processing time: 0.822 seconds
# number of pop_size: 30 and countsize for pop,off 28,1 number of offspring 3 with 60082.4 value
# Processing time: 0.805 seconds
# number of pop_size: 30 and countsize for pop,off 28,2 number of offspring 4 with 64086.4 value
# Processing time: 0.782 seconds
# number of pop_size: 30 and countsize for pop,off 28,3 number of offspring 5 with 61272.2 value
# Processing time: 0.767 seconds
# number of pop_size: 30 and countsize for pop,off 28,4 number of offspring 6 with 60176.4 value
# Processing time: 0.749 seconds
# number of pop_size: 30 and countsize for pop,off 28,5 number of offspring 7 with 61902.6 value
# Processing time: 0.739 seconds
# number of pop_size: 30 and countsize for pop,off 28,6 number of offspring 8 with 64365.2 value
# Processing time: 0.734 seconds
# number of pop_size: 30 and countsize for pop,off 28,7 number of offspring 9 with 58553.6 value
# Processing time: 0.727 seconds
# number of pop_size: 30 and countsize for pop,off 28,8 number of offspring 10 with 59529.8 value
# Processing time: 0.838 seconds
# number of pop_size: 31 and countsize for pop,off 29,0 number of offspring 2 with 63812.2 value
# Processing time: 0.821 seconds
# number of pop_size: 31 and countsize for pop,off 29,1 number of offspring 3 with 62018.8 value
# Processing time: 0.819 seconds
# number of pop_size: 31 and countsize for pop,off 29,2 number of offspring 4 with 63058.6 value
# Processing time: 0.788 seconds
# number of pop_size: 31 and countsize for pop,off 29,3 number of offspring 5 with 60322.8 value
# Processing time: 0.768 seconds
# number of pop_size: 31 and countsize for pop,off 29,4 number of offspring 6 with 61645.6 value
# Processing time: 0.762 seconds
# number of pop_size: 31 and countsize for pop,off 29,5 number of offspring 7 with 64726.4 value
# Processing time: 0.762 seconds
# number of pop_size: 31 and countsize for pop,off 29,6 number of offspring 8 with 65275.6 value
# Processing time: 0.74 seconds
# number of pop_size: 31 and countsize for pop,off 29,7 number of offspring 9 with 58816.8 value
# Processing time: 0.728 seconds
# number of pop_size: 31 and countsize for pop,off 29,8 number of offspring 10 with 58284.8 value
# Processing time: 0.852 seconds
# number of pop_size: 32 and countsize for pop,off 30,0 number of offspring 2 with 66770.0 value
# Processing time: 0.82 seconds
# number of pop_size: 32 and countsize for pop,off 30,1 number of offspring 3 with 61705.6 value
# Processing time: 0.792 seconds
# number of pop_size: 32 and countsize for pop,off 30,2 number of offspring 4 with 60978.2 value
# Processing time: 0.778 seconds
# number of pop_size: 32 and countsize for pop,off 30,3 number of offspring 5 with 62271.4 value
# Processing time: 0.768 seconds
# number of pop_size: 32 and countsize for pop,off 30,4 number of offspring 6 with 61962.8 value
# Processing time: 0.755 seconds
# number of pop_size: 32 and countsize for pop,off 30,5 number of offspring 7 with 60266.4 value
# Processing time: 0.77 seconds
# number of pop_size: 32 and countsize for pop,off 30,6 number of offspring 8 with 61885.0 value
# Processing time: 0.751 seconds
# number of pop_size: 32 and countsize for pop,off 30,7 number of offspring 9 with 59657.2 value
# Processing time: 0.73 seconds
# number of pop_size: 32 and countsize for pop,off 30,8 number of offspring 10 with 62298.4 value
# Processing time: 0.838 seconds
# number of pop_size: 33 and countsize for pop,off 31,0 number of offspring 2 with 67256.0 value
# Processing time: 0.833 seconds
# number of pop_size: 33 and countsize for pop,off 31,1 number of offspring 3 with 64522.6 value
# Processing time: 0.803 seconds
# number of pop_size: 33 and countsize for pop,off 31,2 number of offspring 4 with 65295.6 value
# Processing time: 0.785 seconds
# number of pop_size: 33 and countsize for pop,off 31,3 number of offspring 5 with 61813.6 value
# Processing time: 0.768 seconds
# number of pop_size: 33 and countsize for pop,off 31,4 number of offspring 6 with 62096.4 value
# Processing time: 0.751 seconds
# number of pop_size: 33 and countsize for pop,off 31,5 number of offspring 7 with 60866.6 value
# Processing time: 0.747 seconds
# number of pop_size: 33 and countsize for pop,off 31,6 number of offspring 8 with 61635.8 value
# Processing time: 0.758 seconds
# number of pop_size: 33 and countsize for pop,off 31,7 number of offspring 9 with 61237.8 value
# Processing time: 0.743 seconds
# number of pop_size: 33 and countsize for pop,off 31,8 number of offspring 10 with 62399.2 value
# Processing time: 0.853 seconds
# number of pop_size: 34 and countsize for pop,off 32,0 number of offspring 2 with 64876.8 value
# Processing time: 0.864 seconds
# number of pop_size: 34 and countsize for pop,off 32,1 number of offspring 3 with 65177.6 value
# Processing time: 0.835 seconds
# number of pop_size: 34 and countsize for pop,off 32,2 number of offspring 4 with 64827.0 value
# Processing time: 0.795 seconds
# number of pop_size: 34 and countsize for pop,off 32,3 number of offspring 5 with 62894.8 value
# Processing time: 0.799 seconds
# number of pop_size: 34 and countsize for pop,off 32,4 number of offspring 6 with 59951.6 value
# Processing time: 0.78 seconds
# number of pop_size: 34 and countsize for pop,off 32,5 number of offspring 7 with 61032.8 value
# Processing time: 0.753 seconds
# number of pop_size: 34 and countsize for pop,off 32,6 number of offspring 8 with 61029.8 value
# Processing time: 0.738 seconds
# number of pop_size: 34 and countsize for pop,off 32,7 number of offspring 9 with 59003.8 value
# Processing time: 0.757 seconds
# number of pop_size: 34 and countsize for pop,off 32,8 number of offspring 10 with 63152.0 value
# Processing time: 0.901 seconds
# number of pop_size: 35 and countsize for pop,off 33,0 number of offspring 2 with 63917.4 value
# Processing time: 0.868 seconds
# number of pop_size: 35 and countsize for pop,off 33,1 number of offspring 3 with 64097.0 value
# Processing time: 0.864 seconds
# number of pop_size: 35 and countsize for pop,off 33,2 number of offspring 4 with 61894.8 value
# Processing time: 0.841 seconds
# number of pop_size: 35 and countsize for pop,off 33,3 number of offspring 5 with 62979.6 value
# Processing time: 0.803 seconds
# number of pop_size: 35 and countsize for pop,off 33,4 number of offspring 6 with 61261.6 value
# Processing time: 0.785 seconds
# number of pop_size: 35 and countsize for pop,off 33,5 number of offspring 7 with 60277.4 value
# Processing time: 0.773 seconds
# number of pop_size: 35 and countsize for pop,off 33,6 number of offspring 8 with 58841.8 value
# Processing time: 0.785 seconds
# number of pop_size: 35 and countsize for pop,off 33,7 number of offspring 9 with 59205.4 value
# Processing time: 0.784 seconds
# number of pop_size: 35 and countsize for pop,off 33,8 number of offspring 10 with 64111.2 value
# Processing time: 0.893 seconds
# number of pop_size: 36 and countsize for pop,off 34,0 number of offspring 2 with 62930.0 value
# Processing time: 0.876 seconds
# number of pop_size: 36 and countsize for pop,off 34,1 number of offspring 3 with 63018.4 value
# Processing time: 0.85 seconds
# number of pop_size: 36 and countsize for pop,off 34,2 number of offspring 4 with 61388.2 value
# Processing time: 0.833 seconds
# number of pop_size: 36 and countsize for pop,off 34,3 number of offspring 5 with 62320.4 value
# Processing time: 0.825 seconds
# number of pop_size: 36 and countsize for pop,off 34,4 number of offspring 6 with 60646.4 value
# Processing time: 0.792 seconds
# number of pop_size: 36 and countsize for pop,off 34,5 number of offspring 7 with 64022.2 value
# Processing time: 0.778 seconds
# number of pop_size: 36 and countsize for pop,off 34,6 number of offspring 8 with 60019.8 value
# Processing time: 0.783 seconds
# number of pop_size: 36 and countsize for pop,off 34,7 number of offspring 9 with 59458.8 value
# Processing time: 0.771 seconds
# number of pop_size: 36 and countsize for pop,off 34,8 number of offspring 10 with 64673.0 value
# Processing time: 0.897 seconds
# number of pop_size: 37 and countsize for pop,off 35,0 number of offspring 2 with 65898.6 value
# Processing time: 0.852 seconds
# number of pop_size: 37 and countsize for pop,off 35,1 number of offspring 3 with 62549.8 value
# Processing time: 0.842 seconds
# number of pop_size: 37 and countsize for pop,off 35,2 number of offspring 4 with 62728.6 value
# Processing time: 0.818 seconds
# number of pop_size: 37 and countsize for pop,off 35,3 number of offspring 5 with 62665.8 value
# Processing time: 0.789 seconds
# number of pop_size: 37 and countsize for pop,off 35,4 number of offspring 6 with 60599.4 value
# Processing time: 0.779 seconds
# number of pop_size: 37 and countsize for pop,off 35,5 number of offspring 7 with 61804.6 value
# Processing time: 0.775 seconds
# number of pop_size: 37 and countsize for pop,off 35,6 number of offspring 8 with 64414.8 value
# Processing time: 0.77 seconds
# number of pop_size: 37 and countsize for pop,off 35,7 number of offspring 9 with 61591.6 value
# Processing time: 0.748 seconds
# number of pop_size: 37 and countsize for pop,off 35,8 number of offspring 10 with 60848.6 value
# Processing time: 0.861 seconds
# number of pop_size: 38 and countsize for pop,off 36,0 number of offspring 2 with 67065.4 value
# Processing time: 0.85 seconds
# number of pop_size: 38 and countsize for pop,off 36,1 number of offspring 3 with 62384.4 value
# Processing time: 0.836 seconds
# number of pop_size: 38 and countsize for pop,off 36,2 number of offspring 4 with 62899.2 value
# Processing time: 0.792 seconds
# number of pop_size: 38 and countsize for pop,off 36,3 number of offspring 5 with 63696.2 value
# Processing time: 0.795 seconds
# number of pop_size: 38 and countsize for pop,off 36,4 number of offspring 6 with 65823.2 value
# Processing time: 0.771 seconds
# number of pop_size: 38 and countsize for pop,off 36,5 number of offspring 7 with 62776.8 value
# Processing time: 0.784 seconds
# number of pop_size: 38 and countsize for pop,off 36,6 number of offspring 8 with 67257.6 value
# Processing time: 0.767 seconds
# number of pop_size: 38 and countsize for pop,off 36,7 number of offspring 9 with 63430.0 value
# Processing time: 0.768 seconds
# number of pop_size: 38 and countsize for pop,off 36,8 number of offspring 10 with 63924.4 value
# Processing time: 0.861 seconds
# number of pop_size: 39 and countsize for pop,off 37,0 number of offspring 2 with 69048.2 value
# Processing time: 0.854 seconds
# number of pop_size: 39 and countsize for pop,off 37,1 number of offspring 3 with 67383.0 value
# Processing time: 0.82 seconds
# number of pop_size: 39 and countsize for pop,off 37,2 number of offspring 4 with 70459.4 value
# Processing time: 0.812 seconds
# number of pop_size: 39 and countsize for pop,off 37,3 number of offspring 5 with 60916.0 value
# Processing time: 0.797 seconds
# number of pop_size: 39 and countsize for pop,off 37,4 number of offspring 6 with 61604.4 value
# Processing time: 0.789 seconds
# number of pop_size: 39 and countsize for pop,off 37,5 number of offspring 7 with 61332.0 value
# Processing time: 0.78 seconds
# number of pop_size: 39 and countsize for pop,off 37,6 number of offspring 8 with 60128.4 value
# Processing time: 0.75 seconds
# number of pop_size: 39 and countsize for pop,off 37,7 number of offspring 9 with 64708.0 value
# Processing time: 0.755 seconds
# number of pop_size: 39 and countsize for pop,off 37,8 number of offspring 10 with 60763.4 value
# Processing time: 0.898 seconds
# number of pop_size: 40 and countsize for pop,off 38,0 number of offspring 2 with 67844.2 value
# Processing time: 0.88 seconds
# number of pop_size: 40 and countsize for pop,off 38,1 number of offspring 3 with 66007.6 value
# Processing time: 0.837 seconds
# number of pop_size: 40 and countsize for pop,off 38,2 number of offspring 4 with 65368.8 value
# Processing time: 0.833 seconds
# number of pop_size: 40 and countsize for pop,off 38,3 number of offspring 5 with 63781.6 value
# Processing time: 0.82 seconds
# number of pop_size: 40 and countsize for pop,off 38,4 number of offspring 6 with 63651.0 value
# Processing time: 0.802 seconds
# number of pop_size: 40 and countsize for pop,off 38,5 number of offspring 7 with 63265.6 value
# Processing time: 0.808 seconds
# number of pop_size: 40 and countsize for pop,off 38,6 number of offspring 8 with 61700.4 value
# Processing time: 0.795 seconds
# number of pop_size: 40 and countsize for pop,off 38,7 number of offspring 9 with 67603.2 value
# Processing time: 0.791 seconds
# number of pop_size: 40 and countsize for pop,off 38,8 number of offspring 10 with 64067.2 value
